# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyaganesh-123/CSA6102-DIGITAL-FORENSICS/blob/main/EXP_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import psutil

def capture_volatile_evidence():
    processes = [p.info for p in psutil.process_iter(['pid', 'name'])]
    return {
        "running_process_count": len(processes),
        "sample_processes": processes[:5],
    }


def capture_nonvolatile_evidence(folder):
    if not os.path.exists(folder):
        return {"disk_files": [], "file_count": 0}

    files = sorted(os.listdir(folder))
    return {
        "disk_files": files,
        "file_count": len(files)
    }


# Execute
volatile_snapshot = capture_volatile_evidence()
nonvolatile_snapshot = capture_nonvolatile_evidence("digital_evidence")

# Output
print("Volatile evidence -> running processes:",
      volatile_snapshot["running_process_count"])

print("Sample processes:")
for p in volatile_snapshot["sample_processes"]:
    print(p)

print("\nNon-volatile evidence -> disk files:",
      nonvolatile_snapshot)
# Out:
# Volatile evidence -> running processes: 13
# Sample processes:
# {'pid': 1, 'name': 'docker-init'}
# {'pid': 6, 'name': 'node'}
# {'pid': 20, 'name': 'oom_monitor.sh'}
# {'pid': 22, 'name': 'run.sh'}
# {'pid': 23, 'name': 'kernel_manager_proxy'}
#
# Non-volatile evidence -> disk files: {'disk_files': [], 'file_count': 0}
